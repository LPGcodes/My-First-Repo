# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/Users/gokul-pritha/Documents/python learning/Gender_Inequality_Index.csv')

# %%
df
# Out:
#          Country Human_development    GII   Rank  Maternal_mortality  \
# 0    Switzerland         Very high  0.018    3.0                 5.0
# 1         Norway         Very high  0.016    2.0                 2.0
# 2        Iceland         Very high  0.043    8.0                 4.0
# 3      Hong Kong         Very high    NaN    NaN                 NaN
# 4      Australia         Very high  0.073   19.0                 6.0
# ..           ...               ...    ...    ...                 ...
# 190  South Sudan               Low  0.587  150.0              1150.0
# 191  North Korea               NaN    NaN    NaN                89.0
# 192       Monaco               NaN    NaN    NaN                 NaN
# 193        Nauru               NaN    NaN    NaN                 NaN
# 194      Somalia               NaN    NaN    NaN               829.0
#
#      Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                      2.2              39.8              96.9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Human_development      191 non-null    object
#  2   GII                    170 non-null    float64
#  3   Rank                   170 non-null    float64
#  4   Maternal_mortality     184 non-null    float64
#  5   Adolescent_birth_rate  195 non-null    float64
#  6   Seats_parliament       193 non-null    float64
#  7   F_secondary_educ       177 non-null    float64
#  8   M_secondary_educ       177 non-null    float64
#  9   F_Labour_force         180 non-null    float64
#  10  M_Labour_force         180 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 16.9+ KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 190
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                170 non-null    object
#  1   Human_development      170 non-null    object
#  2   GII                    170 non-null    float64
#  3   Rank                   170 non-null    float64
#  4   Maternal_mortality     170 non-null    float64
#  5   Adolescent_birth_rate  170 non-null    float64
#  6   Seats_parliament       170 non-null    float64
#  7   F_secondary_educ       170 non-null    float64
#  8   M_secondary_educ       170 non-null    float64
#  9   F_Labour_force         170 non-null    float64
#  10  M_Labour_force         170 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 15.9+ KB

# %%
df.columns
# Out:
# Index(['Country', 'Human_development', 'GII', 'Rank', 'Maternal_mortality',
#        'Adolescent_birth_rate', 'Seats_parliament', 'F_secondary_educ',
#        'M_secondary_educ', 'F_Labour_force', 'M_Labour_force'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Country                  169
# Human_development          4
# GII                      152
# Rank                     152
# Maternal_mortality       110
# Adolescent_birth_rate    157
# Seats_parliament         146
# F_secondary_educ         151
# M_secondary_educ         147
# F_Labour_force           140
# M_Labour_force           132
# dtype: int64

# %%
df[['F_secondary_educ','M_secondary_educ']].mean().plot(kind='bar',figsize=(12,6),color=['red','blue'])
plt.title('Male vs Female Education',color='red')
plt.xticks(np.arange(2), ['Female', 'Male'],rotation=False)
# Out:
# ([<matplotlib.axis.XTick at 0x119df5110>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
df[['F_Labour_force','M_Labour_force']].mean().plot(kind='bar',figsize=(12,6),color=['red','blue'])
plt.title('Male vs Female Labour Force',color='red')
plt.xticks(np.arange(2), ['Female', 'Male'],rotation=False)
# Out:
# ([<matplotlib.axis.XTick at 0x119a96fd0>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %%
df['Human_development'].value_counts()
# Out:
# Very high    62
# High         42
# Medium       36
# Low          30
# Name: Human_development, dtype: int64

# %%
df.loc[(df['Human_development']=='Very high')&(df['Country'])]
# Out:
#         Country Human_development    GII  Rank  Maternal_mortality  \
# 0   Switzerland         Very high  0.018   3.0                 5.0
# 1        Norway         Very high  0.016   2.0                 2.0
# 2       Iceland         Very high  0.043   8.0                 4.0
# 4     Australia         Very high  0.073  19.0                 6.0
# 5       Denmark         Very high  0.013   1.0                 4.0
# ..          ...               ...    ...   ...                 ...
# 61     Malaysia         Very high  0.228  57.0                29.0
# 62      Georgia         Very high  0.280  66.0                25.0
# 63    Mauritius         Very high  0.347  82.0                61.0
# 64       Serbia         Very high  0.131  36.0                12.0
# 65     Thailand         Very high  0.333  79.0                37.0
#
#     Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                     2.2              39.8              96.9
# ...

# %%
def country_name(country):
    df_con=df.loc[df['Country']==country]
    df_con[['F_secondary_educ','M_secondary_educ']].mean().plot(kind='bar',figsize=(12,6),color=['red','blue'])
    plt.title('Male vs Female Education',color='red')
    plt.xticks(np.arange(2), ['Female', 'Male'],rotation=False)

# %%
country_name('Thailand')

# %%
def country_name(country):
    df_con=df.loc[df['Country']==country]
    df_con[['F_Labour_force','M_Labour_force']].mean().plot(kind='bar',figsize=(12,6),color=['red','blue'])
    plt.title('Male vs Female Labour Force',color='red')
    plt.xticks(np.arange(2), ['Female', 'Male'],rotation=False)

# %%
country_name('Thailand')

# %%
def Devop(devop):    
    df_dev=df.loc[df['Human_development']==devop]
    df_dev[['F_Labour_force','M_Labour_force']].mean().plot(kind='bar',figsize=(12,6),color=['red','blue'])
    plt.title('Male vs Female labour education',color='red')
    plt.xticks(np.arange(2), ['Female', 'Male'],rotation=False)

# %%
Devop('Very high')

# %%
df_top10=df[df['Rank']<=10]

# %%
df_top10
# Out:
#         Country Human_development    GII  Rank  Maternal_mortality  \
# 0   Switzerland         Very high  0.018   3.0                 5.0
# 1        Norway         Very high  0.016   2.0                 2.0
# 2       Iceland         Very high  0.043   8.0                 4.0
# 5       Denmark         Very high  0.013   1.0                 4.0
# 6        Sweden         Very high  0.023   4.0                 4.0
# 9   Netherlands         Very high  0.025   5.0                 5.0
# 10      Finland         Very high  0.033   6.0                 3.0
# 11    Singapore         Very high  0.040   7.0                 8.0
# 12      Belgium         Very high  0.048  10.0                 5.0
# 16   Luxembourg         Very high  0.044   9.0                 5.0
#
#     Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                     2.2              39.8              96.9
# 1                     2.3              45.0              99.1
# ...

# %%
df_bottom10=df[df['Rank']>160]

# %%
df_bottom10
# Out:
#                       Country Human_development    GII   Rank  \
# 156          Papua New Guinea            Medium  0.725  169.0
# 157                Mauritania            Medium  0.632  161.0
# 162                     Haiti               Low  0.635  163.0
# 163                   Nigeria               Low  0.680  168.0
# 177                   Liberia               Low  0.648  164.0
# 179               Afghanistan               Low  0.678  167.0
# 180              Sierra Leone               Low  0.633  162.0
# 182                     Yemen               Low  0.820  170.0
# 187  Central African Republic               Low  0.672  166.0
# 189                      Chad               Low  0.652  165.0
#
#      Maternal_mortality  Adolescent_birth_rate  Seats_parliament  \
# 156               145.0                   55.3               0.0
# 157               766.0                   78.0              20.3
# 162               480.0                   52.5               2.7
# ...

# %%
df_top10['Maternal_mortality'].mean()
# Out:
# 4.5

# %%
df_bottom10['Maternal_mortality'].mean()
# Out:
# 686.0

# %%
(df_top10['Maternal_mortality'])&(df_bottom10['Maternal_mortality']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     315             try:
# --> 316                 result = libops.scalar_binop(x, y, op)
#     317             except (
#
# ...
